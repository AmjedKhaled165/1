# %%
df=pd.read_csv(r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\Housing.csv")

# %%
df=df.drop_duplicates()

# %%
df.hist(bins=50,figsize=(15,20))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'area'}>],
#        [<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'stories'}>,
#         <Axes: title={'center': 'parking'}>]], dtype=object)

# %%
la_en={}
for column in ['mainroad','guestroom','basement','basement','hotwaterheating','airconditioning','prefarea']:
    la_en[column]=LabelEncoder()
    df[column]=la_en[column].fit_transform(df[column])
df=pd.get_dummies(df,columns=['furnishingstatus'])
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x_train,x_tets,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)
print(len(x_train))
print(len(x_tets))
# Out:
# 436
# 109

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pr=model.predict(x_tets)

# %%
mse=mean_squared_error(y_test,y_pr)

# %%
print(mse)
# Out:
# 829690385060.8578

# %%
joblib.dump(model,r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\Housing.pk1")
# Out:
# ['C:\\Users\\Moldu\\Downloads\\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\\Housing.pk1']

# %%
def pre_hos_price(model,fute):
    input_data=pd.DataFrame([fute],columns=x.columns)
    pred=model.predict(input_data)
    return pred

# %%
user_input={}
for column in x.columns:
    user_input[column]=input(f"enter:{column}")
pred=pre_hos_price(model,user_input)
print('pred:',pred[0])
# Out:
# enter:area7420
# enter:bedrooms4
# enter:bathrooms2
# enter:stories3
# enter:mainroad1
# enter:guestroom0
# enter:basement0
# enter:hotwaterheating0
# enter:airconditioning1
# enter:parking2
# enter:prefarea1
# enter:furnishingstatus_furnished1
# enter:furnishingstatus_semi-furnished0
# enter:furnishingstatus_unfurnished0
# pred: [8153739.90556192]

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import joblib
import pandas as pd
df=pd.read_csv(r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\Housing.csv")
df.drop_duplicates()
df.hist(bins=30,figsize=(10,5))
le_en={}
for col in ['mainroad','guestroom','basement','basement','hotwaterheating','airconditioning','prefarea']:
    le_en[col]=LabelEncoder()
    df[col]=le_en[col].fit_transform(df[col])
df=pd.get_dummies(df,columns=['furnishingstatus'])
x=df.drop('price',axis=1)
y=df['price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=15)
print(len(x_train))
print(len(x_test))
model=LinearRegression().fit(x_train,y_train)
y_pre=model.predict(x_test)
mes=mean_squared_error(y_test,y_pre)
print(mes)
def pre_hs_price(model,fut):
    input_data=pd.DataFrame([fut],columns=x.columns)
    pre=model.pridect(input_data)
    return pre
user_data={}
for col in x.columns:
    user_data[col]=input(f'enter {col}:')
pre=pre_hos_pr(model,user_data)
print(pre)

# %%
# Out:
# 1392016974928.5562

# %%
joblib.dump(model,r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\predict.h5")
# Out:
# ['C:\\Users\\Moldu\\Downloads\\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\\Housing.pd']

# %%
def pre_hos_price(model,fute):
    input_data=pd.DataFrame([fute],columns=x.columns)
    pred=model.predict(input_data)
    return pred

# %%
user_input={}
for column in x.columns:
    user_input[column]=input(f"enter:{column}")
pred=pre_hos_price(model,user_input)
print('pred:',pred[0])

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd
import joblib

# %%
df=pd.read_csv(r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\Housing.csv")
df.drop_duplicates()
df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'area'}>],
#        [<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'stories'}>,
#         <Axes: title={'center': 'parking'}>]], dtype=object)

# %%
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'area'}>],
#        [<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'stories'}>,
#         <Axes: title={'center': 'parking'}>]], dtype=object)

# %%
le_en={}
for col in ['mainroad','guestroom','basement','basement','hotwaterheating','airconditioning','prefarea']:
    le_en[col]=LabelEncoder()
    df[col]=le_en[col].fit_transform(df[col])
df=pd.get_dummies(df,columns=['furnishingstatus'])

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
model=LinearRegression().fit(x_train,y_train)

# %%
y_pre=model.predict(x_test)

# %%
mes=mean_squared_error(y_test,y_pre)

# %%
mes
# Out:
# 1394821159283.8777

# %%
joblib.dump(model,r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\Housing.pd")
# Out:
# ['C:\\Users\\Moldu\\Downloads\\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\\Housing.pd']

# %%
def pre_hos_pri(model,fut):
    input_data=pd.DataFrame(df,columns=x.columns)
    pre=model.predict(input_data)
    return pre

# %%
use_data={}
for col in x.columns:
    use_data[col]=input(f'enter{col}:')
pre=pre_hos_pri(model,use_data)
print(pre[0])
# Out:
# enterarea:
# enterbedrooms:1
# enterbathrooms:1
# enterstories:1
# entermainroad:1
# enterguestroom:1
# enterbasement:1
# enterhotwaterheating:1
# enterairconditioning:1
# enterparking:1
# enterprefarea:1
# enterfurnishingstatus_furnished:0
# enterfurnishingstatus_semi-furnished:1
# enterfurnishingstatus_unfurnished:0
# 8040334.105235292

# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import joblib
df=pd.read_csv(r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\Housing.csv")
df=df.drop_duplicates()
df.hist(bins=50,figsize=(15,20))
la_en={}
for column in ['mainroad','guestroom','basement','basement','hotwa terheating','airconditioning','prefarea']:
    la_en[column]=LabelEncoder()
    df[column]=la_en[column].fit_transform(df[column])
df=pd.get_dummies(df,columns=['furnishingstatus'])
x=df.drop('price',axis=1)
y=df['price']
x_train,x_tets,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)
print(len(x_train))
print(len(x_tets))
model=LinearRegression()
model.fit(x_train,y_train)
y_pr=model.predict(x_tets)
mse=mean_squared_error(y_test,y_pr)
print(mse)
joblib.dump(model,r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\Housing.pk1")
def pre_hos_price(model,fute):
    input_data=pd.DataFrame([fute],columns=x.columns)
    pred=model.predict(input_data)
    return pred
user_input={}
for column in x.columns:
    user_input[column]=input(f"enter:{column}")
pred=pre_hos_price(model,user_input)
print('pred:',pred[0])

# %%
dff=pd.read_excel(r"C:\Users\Moldu\Downloads\fcf25a2a356842fb0f306974e53c2eab-61dc4eb6ee95930b23287e515ee059207bc49905\report.xlsx")
# Out:
#                                         1- Summarized Unnamed: 1
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                     2- Data type is structured data        NaN
# 3                                                 NaN        NaN
# 4                          3- Data type split 2 type:        NaN
# 5                                                 NaN        NaN
# 6                                       a-categorized        NaN
# 7                                     b-uncategorized        NaN
# 8                                     4-bias problem         NaN
# 9            a-Data augmentation 0 to 00000000,3to...        NaN
# 10                                b-model selection          NaN
# 11                                     c-balance data        NaN
# 12                                             5-logo        NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dff.columns
#
# NameError: name 'dff' is not defined
